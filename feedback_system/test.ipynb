# %%
import sys
import os
from pathlib import Path
# Add the utils directory to sys.path
print(sys.path)
sys.path.append(str(Path(os.getcwd()).resolve().parents[2]))
import torch
from utils.config import update_config 
from alphapose.models import builder

cfg = update_config("../alphapose/configs/256x192_res50_lr1e-3_1x.yaml")
model = builder.build_sppe(cfg.MODEL, preset_cfg=cfg.DATA_PRESET)

if cfg.MODEL.PRETRAINED:
    model_path = os.path.join("../alphapose", cfg.MODEL.PRETRAINED)
    model.load_state_dict(torch.load(model_path))
        

model.load_state_dict(torch.load("../alphapose/pretrained_models/RegLoss100EpochNoFlipDPG.pth", map_location="cpu"))  # Load state_dict safely
model.eval()

for name, param in model.named_parameters():
    print(f"Layer: {name}")
    print(f"Mean: {param.data.mean()}, Std: {param.data.std()}, Min: {param.data.min()}, Max: {param.data.max()}")
    print("-" * 50)
# Out:
# ['c:\\Users\\britt\\OneDrive - Luleå University of Technology\\SkiersProject\\Code\\SkiersProject\\feedback_system', 'c:\\Users\\britt\\anaconda3\\envs\\alphapose\\python37.zip', 'c:\\Users\\britt\\anaconda3\\envs\\alphapose\\DLLs', 'c:\\Users\\britt\\anaconda3\\envs\\alphapose\\lib', 'c:\\Users\\britt\\anaconda3\\envs\\alphapose', '', 'C:\\Users\\britt\\AppData\\Roaming\\Python\\Python37\\site-packages', 'c:\\users\\britt\\alphapose', 'C:\\Users\\britt\\AppData\\Roaming\\Python\\Python37\\site-packages\\natsort-8.4.0-py3.7.egg', 'C:\\Users\\britt\\AppData\\Roaming\\Python\\Python37\\site-packages\\timm-0.1.20-py3.7.egg', 'C:\\Users\\britt\\AppData\\Roaming\\Python\\Python37\\site-packages\\munkres-1.1.4-py3.7.egg', 'c:\\Users\\britt\\anaconda3\\envs\\alphapose\\lib\\site-packages', 'c:\\Users\\britt\\anaconda3\\envs\\alphapose\\lib\\site-packages\\win32', 'c:\\Users\\britt\\anaconda3\\envs\\alphapose\\lib\\site-packages\\win32\\lib', 'c:\\Users\\britt\\anaconda3\\envs\\alphapose\\lib\\site-packages\\Pythonwin', 'c:\\Users\\britt\\anaconda3\\envs\\alphapose\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\britt\\.ipython', 'C:\\Users\\britt\\OneDrive - Luleå University of Technology\\SkiersProject\\Code', 'C:\\Users\\britt\\OneDrive - Luleå University of Technology\\SkiersProject\\Code', 'C:\\Users\\britt\\OneDrive - Luleå University of Technology\\SkiersProject\\Code\\SkiersProject', 'C:\\Users\\britt\\OneDrive - Luleå University of Technology\\SkiersProject', 'C:\\Users\\britt\\OneDrive - Luleå University of Technology\\SkiersProject', 'C:\\Users\\britt\\OneDrive - Luleå University of Technology\\SkiersProject', 'C:\\Users\\britt\\OneDrive - Luleå University of Technology\\SkiersProject', 'C:\\Users\\britt\\OneDrive - Luleå University of Technology\\SkiersProject', 'C:\\Users\\britt\\OneDrive - Luleå University of Technology\\SkiersProject']
# c:\Users\britt\anaconda3\envs\alphapose\lib\site-packages\torchvision\models\_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# c:\Users\britt\anaconda3\envs\alphapose\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28940\3941139855.py in <module>
#      14 if cfg.MODEL.PRETRAINED:
#      15     model_path = os.path.join("..alphapose", cfg.MODEL.PRETRAINED)
# ---> 16     model.load_state_dict(torch.load(model_path))
#      17
#      18
#
# c:\Users\britt\anaconda3\envs\alphapose\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     697         pickle_load_args['encoding'] = 'utf-8'
#     698
# --> 699     with _open_file_like(f, 'rb') as opened_file:
#     700         if _is_zipfile(opened_file):
#     701             # The zipfile reader is going to advance the current file position.
#
# c:\Users\britt\anaconda3\envs\alphapose\lib\site-packages\torch\serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# c:\Users\britt\anaconda3\envs\alphapose\lib\site-packages\torch\serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '..alphapose\\pretrained_models/RegLoss100EpochNoFlipDPG.pth'
